# %%
import pandas as pd
import numpy as np
from pathlib import Path

# %%
DATA = Path("../data/processed/merged_aqi.csv")

df = pd.read_csv(DATA)

print("="*60)
print("AQI DATASET LOADED")
print("="*60)

print(f"Rows    : {df.shape[0]}")
print(f"Columns : {df.shape[1]}")

df.head()
