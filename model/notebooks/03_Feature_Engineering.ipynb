# %%
import pandas as pd
import numpy as np
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 import pandas as pd
#       2 import numpy as np
#
# File c:\Users\Krushna\Documents\Git\Asthma-Predictor_final\model\.venv\Lib\site-packages\pandas\__init__.py:23
#      21 for _dependency in _hard_dependencies:
#      22     try:
# ---> 23         __import__(_dependency)
#      24     except ImportError as _e:  # pragma: no cover
#      25         raise ImportError(
#      26             f"Unable to import required dependency {_dependency}. "
#      27             "Please see the traceback for details."
#      28         ) from _e
#
# File c:\Users\Krushna\Documents\Git\Asthma-Predictor_final\model\.venv\Lib\site-packages\numpy\__init__.py:122
#     119 from . import _distributor_init
#     121 try:
# --> 122     from numpy.__config__ import show_config
#     123 except ImportError as e:
# ...
